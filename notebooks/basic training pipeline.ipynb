# %% [markdown]
# # Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import datatable as dt
import sys
sys.path.append("..")

# CREATE THE DATA_DIR PATH
from pathlib import Path
DATA_DIR = Path('./data/')

# %% [markdown]
# # Load data

# %%
from modules.pipeline import load_data

# %%
data = load_data(DATA_DIR, 'first_version_train.csv')

# %% [markdown]
# # Transforming data for the model

# %%
data.describe()
# Out:
#                date    feature_93   feature_118   feature_117    feature_51  \
# count  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06
# mean   2.473574e+02  3.246773e-01  3.849311e-01  3.022950e-01  4.928623e-01
# std    1.528486e+02  2.152026e+00  2.366299e+00  2.433219e+00  2.817234e+00
# min    0.000000e+00 -1.746285e+00 -3.202494e+00 -4.159270e+00 -5.273409e+00
# 25%    1.030000e+02 -8.933974e-01 -9.256586e-01 -1.132848e+00 -7.499238e-01
# 50%    2.530000e+02 -5.505853e-02  6.384654e-03 -7.722104e-02  2.890715e-02
# 75%    3.820000e+02  9.580755e-01  1.154869e+00  1.199051e+00  1.024069e+00
# max    4.990000e+02  1.128524e+02  1.784405e+02  9.653914e+01  1.979183e+02
#
#          feature_16    feature_11    feature_52    feature_10    feature_41  \
# count  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06
# mean   1.374475e-01  9.732797e-02  4.894156e-03  1.723723e-01  3.897169e-01
# std    2.137285e+00  1.548966e+00  1.875148e+00  1.646480e+00  1.979227e+00
# min   -5.549069e+01 -3.032871e+01 -5.785880e+00 -5.682901e+01 -4.950679e+00
# 25%   -1.091044e+00 -6.292713e-01 -1.509645e+00 -7.826904e-01 -8.103882e-01
# 50%   -2.359242e-02  1.539982e-03 -8.178716e-02 -1.854513e-02 -5.171744e-02
# 75%    1.199377e+00  7.525565e-01  1.359763e+00  9.258294e-01  1.124165e+00
# max    6.200528e+01  3.965424e+01  6.629657e+00  5.470133e+01  2.584472e+01
#
#        ...   feature_122   feature_128    feature_53   feature_120  \
# count  ...  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06
# mean   ...  2.638919e-01  2.465135e-01  3.109241e-01  2.242823e-01
# std    ...  2.050523e+00  2.267801e+00  2.138367e+00  1.810286e+00
# min    ... -5.862979e+00 -7.024909e+00 -5.344403e+00 -4.883486e+00
# 25%    ... -1.173396e+00 -1.351376e+00 -1.173441e+00 -1.092604e+00
# 50%    ... -6.189149e-02 -7.120204e-02 -3.517699e-02 -7.306343e-02
# 75%    ...  1.313283e+00  1.473971e+00  1.387558e+00  1.225302e+00
# max    ...  4.812516e+01  5.119038e+01  4.731695e+01  5.280387e+01
#
#           feature_9   feature_124     feature_1   feature_126    feature_42  \
# count  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06  1.993372e+06
# mean   2.699504e-01  2.339804e-01  4.166007e-01  2.136651e-01  4.397250e-01
# std    2.328695e+00  1.670982e+00  2.532780e+00  2.481993e+00  2.416368e+00
# min   -3.419819e+01 -4.080720e+00 -3.172026e+00 -8.215050e+00 -7.097649e+00
# 25%   -1.229536e+00 -9.741961e-01 -1.258164e+00 -1.546594e+00 -1.312486e+00
# 50%    1.014370e-02 -7.475740e-02  2.587801e-02 -9.408076e-02  8.871442e-02
# 75%    1.491688e+00  1.114537e+00  1.591639e+00  1.627972e+00  1.820562e+00
# max    4.146828e+01  5.988318e+01  7.442989e+01  5.872849e+01  2.342762e+01
#
#          feature_69
# count  1.993372e+06
# mean   4.100866e-01
# std    2.264925e+00
# min   -2.810803e+00
# 25%   -1.070996e+00
# 50%    3.912943e-02
# 75%    1.469226e+00
# max    5.232830e+01
#
# [8 rows x 25 columns]

# %% [markdown]
# # predictor and variable

# %%
X = data.drop('action', axis=1)

# %%
X.head(3)
# Out:
#    date  feature_93  feature_118  feature_117  feature_51  feature_16  \
# 0     0    0.268165    -1.812644     0.285151    0.400071   -1.045913
# 1     0   -0.006777    -0.672916    -1.281847   -0.172306    1.070328
# 2     0   -0.641936     0.928793     0.463747    2.304336   -1.289940
#
#    feature_11  feature_52  feature_10  feature_41  ...  feature_122  \
# 0   -0.710505    1.732091   -0.815505    0.238448  ...     0.528743
# 1    2.015274    1.820407    0.915851   -2.049727  ...     3.047750
# 2   -0.853292    4.387984   -1.783306    0.870839  ...    -0.463486
#
#    feature_128  feature_53  feature_120  feature_9  feature_124  feature_1  \
# 0     1.023031    0.662062     1.635075   0.455843     1.610215   0.086238
# 1     3.322019    3.211434     4.213683   2.721408     3.513960   2.540471
# 2    -0.734133   -1.225501    -0.325481  -2.764325    -0.388679  -1.501931
#
#    feature_126  feature_42  feature_69
# 0     2.236798    1.706032    1.766712
# 1     3.726736    3.328481    2.264585
# 2    -0.716593   -1.256370   -1.909002
#
# [3 rows x 25 columns]

# %%
y = data['action']

# %%
y[:3]
# Out:
# 0     True
# 1     True
# 2    False
# Name: action, dtype: bool

# %% [markdown]
# # Splitting data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (1495029, 25) (1495029,)
# Test set: (498343, 25) (498343,)

# %% [markdown]
# # Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Fake model

# %%
Class

# %%
y_pred =
